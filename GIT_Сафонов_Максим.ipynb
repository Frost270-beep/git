# %% [markdown]
# <font face="times new roman" size="3" >
# <center> МИНИСТЕРСТВО ЦИФРОВОГО РАЗВИТИЯ, СВЯЗИ И МАССОВЫХ КОММУНИКАЦИЙ РОССИЙСКОЙ ФЕДЕРАЦИИ </center>
# <center>Ордена Трудового Красного Знамени федеральное государственное бюджетное образовательное учреждение высшего образования </center>
# <center> <strong> «Московский технический университет связи и информатики» </strong> </center>
#
#   <hr>
# <center> Кафедра «Телевидения и звукового вещания им. С.И. Катаева (ТиЗВ)» </center>
# <br>
# <center> <font face="times new roman" size="3" > Отчет по лабораторной работе №12 </center>
# <center>по дисциплине </center>
# <center><b>«Введение в информационные технологии»</b></center>
# <center>на тему</center>
# <center><b>«GIT»
# </b> </center>
#
# </font>
#
#   <br><br><br><br><br>
#   <p  align="right"> <font face="times new roman" size="3" > Выполнил: студент группы </p>
#   <p  align="right"> <font face="times new roman" size="3" >       БИК2502 </p>
#   <p  align="right"> <font face="times new roman" size="3" > Сафонов Максим Дмитриевич</p>
#   <p  align="right"> <font face="times new roman" size="3" > Проверил:</p>
#   <p  align="right"> <font face="times new roman" size="3" > Старший преподаватель Егоров Дмитрий Аркадьевич</p>
#   <br>
#   <br>
#   <p  align="center"> <font face="times new roman" size="2" > Москва, 2025 г. </p>
#
#   <hr>

# %% [markdown]
# <font face="times new roman" size="4">
# <center><b>Цель работы</b>
#
# <br>
#
# Изучить основные принципы работы с системой контроля версий Git, научиться создавать локальный репозиторий, выполнять коммиты, работать с ветками и слиянием, а также освоить публикацию проекта на удалённом репозитории GitHub.

# %% [markdown]
# <font face="times new roman" size="4"> <center><b>Процесс выполнения</b>
# <br>
#
# 1. Для выполнения лабораторной работы была установлена система контроля версий Git.
# Загрузка установочного файла выполнена с официального сайта https://gitforwindows.org/
# . После скачивания был запущен установщик Git-2.X.X-64-bit.exe, и все параметры оставлены по умолчанию.
# После завершения установки программа Git Bash появилась в меню «Пуск».
# Проверка установки выполнена командой:

# %%
git --version

# %% [markdown]
# <font face="times new roman" size="3" >
# <center>
# В ответ выведен номер установленной версии Git, что подтвердило успешную установку.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <font face="times new roman" size="3" >
# <center>
# 2. После установки выполнена настройка имени пользователя и адреса электронной почты, которые будут отображаться в истории коммитов.
# Команды:

# %%
git config --global user.name "max002700"
git config --global user.email "max002700@gmail.com"

# %% [markdown]
# <font face="times new roman" size="3" >
# <center>
# Проверка параметров выполнена командой git config --list. В выводе отобразились установленные значени
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <font face="times new roman" size="3" >
# <center>
# 3. Для практической работы на рабочем столе создана папка проекта GIT. В ней будет храниться отчёт и другие файлы.
# В Git Bash выполнены команды:

# %%
cd /c/Users/user/Desktop
mkdir GIT
cd GIT
git init

# %% [markdown]
# <font face="times new roman" size="3" >
# <center>
# После выполнения команды git init в папке появился скрытый каталог .git, что означает создание нового локального репозитория.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <font face="times new roman" size="3" >
# <center>
# 4. В папке проекта создан файл GIT_Сафонов_Максим.ipynb (отчёт по лабораторной работе). После этого в файл добавлены первые строки текста. Проверка состояния репозитория выполнена командой:
